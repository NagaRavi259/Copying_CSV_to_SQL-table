# %% [markdown]
# ## Inserting the CSV Data into the DataBase to simmulate the production Errors or fixingthe bugs
# - In this File we will learn how to insert or upload the CSV Data into the Database using the simple python script

# %%
#code to send CSV data to DataBase Table
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote  

#engine = create_engine("postgresql://postgres@localhost:5432/postgres", echo=False)
engine = create_engine('postgresql://postgres:%s@localhost:5432/postgres' % quote('postgres'))
#df = pd.read_csv("C:/Users/vnaga/Desktop/of/test/EnneWood_Data_12-05-2022_to_13-05-2022.csv", header=0)
df.to_sql("Tabel_name", con=engine)

# %%
#code to send CSV data to DataBase Table
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote  

#engine = create_engine("postgresql://postgres@localhost:5432/postgres", echo=False)
engine = create_engine('postgresql://postgres:%s@localhost:5432/postgres' % quote('postgres'))
df = pd.read_csv(r"C:\Users\vnaga\OneDrive\Python files\DataBase\CSV_file.csv", header=0)

# %%
#to convert string data to dateTime
df.DBTime=pd.to_datetime(df.DBTime)

# %%
df.to_sql("Table_Name", con=engine)

# %%
type(pd.to_datetime(df.DBTime))
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#                             CreatedTime                SystemTime  SiteId  \
# 0      2022-05-16 05:59:59.443000+00:00 2022-05-16 06:00:14+00:00       1
# 1      2022-05-16 05:59:58.430000+00:00 2022-05-16 06:00:13+00:00       1
# 2      2022-05-16 05:59:57.430000+00:00 2022-05-16 06:00:12+00:00       1
# 3      2022-05-16 05:59:56.430000+00:00 2022-05-16 06:00:11+00:00       1
# 4      2022-05-16 05:59:55.413000+00:00 2022-05-16 06:00:10+00:00       1
# ...                                 ...                       ...     ...
# 517834 2022-05-10 06:00:04.397000+00:00 2022-05-10 06:00:17+00:00       1
# 517835 2022-05-10 06:00:03.380000+00:00 2022-05-10 06:00:16+00:00       1
# 517836 2022-05-10 06:00:02.380000+00:00 2022-05-10 06:00:15+00:00       1
# 517837 2022-05-10 06:00:01.367000+00:00 2022-05-10 06:00:14+00:00       1
# 517838 2022-05-10 06:00:00.367000+00:00 2022-05-10 06:00:13+00:00       1
#
#                                  DBTime  DeviceId  Hot_air_F_H_oil_fr__PV  \
# ...

# %%
df.DBTime=pd.to_datetime(df.DBTime)
